# %%
from ants import *

# %%
 beehive, layout = Hive(AssaultPlan()), dry_layout

# %%
dimensions = (1, 9)

# %%
gamestate = GameState(beehive, ant_types(), layout, dimensions)

# %%
place = gamestate.places['tunnel_0_4']

# %%
fire = FireAnt(health=1)

# %%
place.add_insect(fire)

# %%
place.add_insect(Bee(3))

# %%
place.add_insect(Bee(5))

# %%
len(place.bees)
# Out:
# 2

# %%
place.bees[0].action(gamestate)  # The first Bee attacks FireAnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-54fda6011100> in <module>
# ----> 1 place.bees[0].action(gamestate)  # The first Bee attacks FireAnt
#
# f:\code\code_py\cs61a\ants\ants.py in action(self, gamestate)
#     499         or moves to the exit of its current place otherwise.
#     500
# --> 501         gamestate -- The GameState, used to access game state information.
#     502         """
#     503         destination = self.place.exit
#
# f:\code\code_py\cs61a\ants\ants.py in sting(self, ant)
#     475
#     476     name = 'Bee'
# --> 477     damage = 1
#     478     is_waterproof = True
#     479
#
# f:\code\code_py\cs61a\ants\ants.py in reduce_health(self, amount)
#     265                 # print("Debug bee health: \n", bee.health)
#     266                 bee.reduce_health(amount)
# --> 267                 # print("Debug bee health: \n", bee.health)
#     268
#     269         Ant.reduce_health(self, amount)
#
# NameError: name 'damage' is not defined
