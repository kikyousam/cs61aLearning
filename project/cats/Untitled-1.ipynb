# %%
from utils import (
    lower,
    split,
    remove_punctuation,
    lines_from_file,
    count,
    deep_convert_to_tuple,
)
p = 'A paragraph about cats.'
lp = [lower(x) for x in p]

# %%
p = [[75, 81, 84, 90, 92], [19, 29, 35, 36, 38]]
print(len(p))

# %%
for i in range(2):
    print(i)

# %%
a = [10]
b = a
a == b
# Out:
# True

# %%
a.append(20)
a == b
# Out:
# True

# %%
a
# Out:
# [10, 20]

# %%
b
# Out:
# [10, 20]

# %%
y = [6,7,8]
x = y
x is y
# Out:
# True

# %%
y = [3]

# %%
x is y
# Out:
# False
